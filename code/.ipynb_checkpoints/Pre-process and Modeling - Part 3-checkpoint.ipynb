# %% [markdown]
# ### Pre-process and Modeling
# ---

# %% [markdown]
# #### Section

# %% [markdown]
# - [Import libraries and Load Data](#Import-Libraries-and-Load-Data)
# - [Pre-process](#Pre-process)
# - [Modeling](#Modeling)
# - [Conclusion and Recommendation](#Conclusion-and-Recommendation)

# %% [markdown]
# #### Import Libraries and Load Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt
from datetime import timedelta
sns.set_style('whitegrid')
from functools import reduce
# %matplotlib inline
from matplotlib import dates
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from statsmodels.tools.eval_measures import mse,rmse
from chart_studio.plotly import plot_mpl
from pmdarima.arima import auto_arima
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.seasonal import seasonal_decompose
pd.set_option('display.max_rows', 2060)
pd.set_option('display.max_columns', 75)

# %%
# Import data from combined_clean csv
final_df = pd.read_csv(r'..\datasets\final_df_3.csv')
# Set date as index and sort from oldest to latest 
final_df.set_index('date', inplace=True)
final_df.sort_index(inplace=True)

# %%
final_df.head()
# Out:
#              eur/usd   gbp/usd     usd/jpy   usd/chf   usd_index  wti_crude  \
# date
# 1999-01-31  1.159910  1.650562  113.334762  1.385376   94.583333  12.471429
# 1999-02-28  1.120615  1.627655  116.682500  1.427245   97.070000  11.988500
# 1999-03-31  1.088370  1.621683  119.534783  1.462683   99.405217  14.682174
# 1999-04-30  1.070041  1.608532  119.793182  1.494573  100.468182  17.286364
# 1999-05-31  1.062510  1.614914  121.948095  1.508067  101.003333  17.702857
#
#                  nasdaq       cac_40    gold_usd  fed_rate  euro_libor  \
# date
# 1999-01-31  2353.067619  4137.265238  287.516667      4.75    3.136190
# 1999-02-28  2354.832500  4124.204500  287.757500      4.75    3.093500
# 1999-03-31  2391.140000  4139.752174  285.934783      4.75    3.048261
# 1999-04-30  2538.894545  4324.717273  282.563636      4.75    2.696818
# 1999-05-31  2507.806190  4358.982381  276.761905      4.75    2.580000
#
#             us_unemp  eu_unemp  us_retail  eu_retail  us_core_cpi  Year
# date
# 1999-01-31       4.3      10.1        6.6        1.8          2.4  1999
# 1999-02-28       4.4      10.0        7.7        2.3          2.1  1999
# 1999-03-31       4.2       9.9        7.6        3.4          2.1  1999
# 1999-04-30       4.3       9.9        7.0        2.2          2.2  1999
# 1999-05-31       4.2       9.9        7.5        1.3          2.0  1999

# %%
# Check data type, shape and ensure no null values
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 252 entries, 1999-01-31 to 2019-12-31
# Data columns (total 17 columns):
# eur/usd        252 non-null float64
# gbp/usd        252 non-null float64
# usd/jpy        252 non-null float64
# usd/chf        252 non-null float64
# usd_index      252 non-null float64
# wti_crude      252 non-null float64
# nasdaq         252 non-null float64
# cac_40         252 non-null float64
# gold_usd       252 non-null float64
# fed_rate       252 non-null float64
# euro_libor     252 non-null float64
# us_unemp       252 non-null float64
# eu_unemp       252 non-null float64
# us_retail      252 non-null float64
# eu_retail      252 non-null float64
# us_core_cpi    252 non-null float64
# Year           252 non-null int64
# dtypes: float64(16), int64(1)
# memory usage: 35.4+ KB

# %% [markdown]
# ### Pre-process

# %% [markdown]
# #### Test For Stationarity - Augmented Dickey-Fuller Test

# %%
# Run the dickey fuller test for all columns in the data set to ensure they are stationary
def adf_test(df):
    result = adfuller(df.dropna(),autolag='AIC')
    labels = ['ADF Test Statistic','p-value','# Lags','# Observations']
    out = pd.Series(result[0:4],index=labels)
    
    for key,val in result[4].items():
        out[f'critical value ({key})']=val
        
    print(out.to_string())          
    
    if result[1] <= 0.05:
        print('Data is stationary')
    else:
        print('Data is non-stationary')
        
for i in final_df.columns:
    print('Column Name: ',i)
    print('------------------------')
    adf_test(final_df[i])
    print('\n')
# Out:
# Column Name:  eur/usd
# ------------------------
# ADF Test Statistic       -1.819444
# p-value                   0.370852
# # Lags                    1.000000
# # Observations          250.000000
# critical value (1%)      -3.456781
# critical value (5%)      -2.873172
# critical value (10%)     -2.572969
# Data is non-stationary
#
#
# Column Name:  gbp/usd
# ------------------------
# ADF Test Statistic       -1.508033
# p-value                   0.529534
# # Lags                    1.000000
# # Observations          250.000000
# critical value (1%)      -3.456781
# critical value (5%)      -2.873172
# critical value (10%)     -2.572969
# Data is non-stationary
#
#
# Column Name:  usd/jpy
# ------------------------
# ADF Test Statistic       -2.227932
# p-value                   0.196264
# # Lags                    2.000000
# # Observations          249.000000
# critical value (1%)      -3.456888
# critical value (5%)      -2.873219
# critical value (10%)     -2.572994
# Data is non-stationary
#
#
# Column Name:  usd/chf
# ------------------------
# ADF Test Statistic       -1.515072
# p-value                   0.526043
# # Lags                   12.000000
# # Observations          239.000000
# critical value (1%)      -3.458011
# critical value (5%)      -2.873710
# critical value (10%)     -2.573256
# Data is non-stationary
#
#
# Column Name:  usd_index
# ------------------------
# ADF Test Statistic       -1.626645
# p-value                   0.469247
# # Lags                    1.000000
# # Observations          250.000000
# critical value (1%)      -3.456781
# critical value (5%)      -2.873172
# critical value (10%)     -2.572969
# Data is non-stationary
#
#
# Column Name:  wti_crude
# ------------------------
# ADF Test Statistic       -2.663073
# p-value                   0.080649
# # Lags                    1.000000
# # Observations          250.000000
# critical value (1%)      -3.456781
# critical value (5%)      -2.873172
# critical value (10%)     -2.572969
# Data is non-stationary
#
#
# Column Name:  nasdaq
# ------------------------
# ADF Test Statistic        2.140363
# p-value                   0.998830
# # Lags                   13.000000
# # Observations          238.000000
# critical value (1%)      -3.458128
# critical value (5%)      -2.873762
# critical value (10%)     -2.573283
# Data is non-stationary
#
#
# Column Name:  cac_40
# ------------------------
# ADF Test Statistic       -2.563259
# p-value                   0.100831
# # Lags                    7.000000
# # Observations          244.000000
# critical value (1%)      -3.457438
# critical value (5%)      -2.873459
# critical value (10%)     -2.573122
# Data is non-stationary
#
#
# Column Name:  gold_usd
# ------------------------
# ADF Test Statistic       -0.824419
# p-value                   0.811844
# # Lags                    1.000000
# # Observations          250.000000
# critical value (1%)      -3.456781
# critical value (5%)      -2.873172
# critical value (10%)     -2.572969
# Data is non-stationary
#
#
# Column Name:  fed_rate
# ------------------------
# ADF Test Statistic       -3.368831
# p-value                   0.012068
# # Lags                    9.000000
# # Observations          242.000000
# critical value (1%)      -3.457664
# critical value (5%)      -2.873559
# critical value (10%)     -2.573175
# Data is stationary
#
#
# Column Name:  euro_libor
# ------------------------
# ADF Test Statistic       -1.360021
# p-value                   0.601285
# # Lags                   15.000000
# # Observations          236.000000
# critical value (1%)      -3.458366
# critical value (5%)      -2.873866
# critical value (10%)     -2.573339
# Data is non-stationary
#
#
# Column Name:  us_unemp
# ------------------------
# ADF Test Statistic       -2.078230
# p-value                   0.253358
# # Lags                    6.000000
# # Observations          245.000000
# critical value (1%)      -3.457326
# critical value (5%)      -2.873410
# critical value (10%)     -2.573096
# Data is non-stationary
#
#
# Column Name:  eu_unemp
# ------------------------
# ADF Test Statistic       -2.307626
# p-value                   0.169520
# # Lags                    6.000000
# # Observations          245.000000
# critical value (1%)      -3.457326
# critical value (5%)      -2.873410
# critical value (10%)     -2.573096
# Data is non-stationary
#
#
# Column Name:  us_retail
# ------------------------
# ADF Test Statistic       -3.449799
# p-value                   0.009374
# # Lags                   14.000000
# # Observations          237.000000
# critical value (1%)      -3.458247
# critical value (5%)      -2.873814
# critical value (10%)     -2.573311
# Data is stationary
#
#
# Column Name:  eu_retail
# ------------------------
# ADF Test Statistic       -2.602342
# p-value                   0.092514
# # Lags                   15.000000
# # Observations          236.000000
# critical value (1%)      -3.458366
# critical value (5%)      -2.873866
# critical value (10%)     -2.573339
# Data is non-stationary
#
#
# Column Name:  us_core_cpi
# ------------------------
# ADF Test Statistic       -2.411309
# p-value                   0.138570
# # Lags                   12.000000
# # Observations          239.000000
# critical value (1%)      -3.458011
# critical value (5%)      -2.873710
# critical value (10%)     -2.573256
# Data is non-stationary
#
#
# Column Name:  Year
# ------------------------
# ADF Test Statistic        0.644034
# p-value                   0.988652
# # Lags                   11.000000
# # Observations          240.000000
# critical value (1%)      -3.457894
# critical value (5%)      -2.873659
# critical value (10%)     -2.573229
# Data is non-stationary

# %%
# Notice all columns apart from fed_rate, us_retail, us_indus, eu_indus, us_cpi, are non-stationary
# Difference the columns by 1 and test again, notice eu_indus is still non stationary
final_differ = final_df.diff(1).dropna()

for i in final_differ.columns:
    print('Column Name: ',i)
    print('------------------------')
    adf_test(final_differ[i])
    print('\n')
# Out:
# Column Name:  eur/usd
# ------------------------
# ADF Test Statistic     -1.168515e+01
# p-value                 1.704120e-21
# # Lags                  0.000000e+00
# # Observations          2.500000e+02
# critical value (1%)    -3.456781e+00
# critical value (5%)    -2.873172e+00
# critical value (10%)   -2.572969e+00
# Data is stationary
#
#
# Column Name:  gbp/usd
# ------------------------
# ADF Test Statistic     -1.193130e+01
# p-value                 4.774472e-22
# # Lags                  0.000000e+00
# # Observations          2.500000e+02
# critical value (1%)    -3.456781e+00
# critical value (5%)    -2.873172e+00
# critical value (10%)   -2.572969e+00
# Data is stationary
#
#
# Column Name:  usd/jpy
# ------------------------
# ADF Test Statistic     -8.901067e+00
# p-value                 1.171009e-14
# # Lags                  1.000000e+00
# # Observations          2.490000e+02
# critical value (1%)    -3.456888e+00
# critical value (5%)    -2.873219e+00
# critical value (10%)   -2.572994e+00
# Data is stationary
#
#
# Column Name:  usd/chf
# ------------------------
# ADF Test Statistic     -1.074700e+01
# p-value                 2.725669e-19
# # Lags                  1.000000e+00
# # Observations          2.490000e+02
# critical value (1%)    -3.456888e+00
# critical value (5%)    -2.873219e+00
# critical value (10%)   -2.572994e+00
# Data is stationary
#
#
# Column Name:  usd_index
# ------------------------
# ADF Test Statistic     -1.004338e+01
# p-value                 1.476009e-17
# # Lags                  1.000000e+00
# # Observations          2.490000e+02
# critical value (1%)    -3.456888e+00
# critical value (5%)    -2.873219e+00
# critical value (10%)   -2.572994e+00
# Data is stationary
#
#
# Column Name:  wti_crude
# ------------------------
# ADF Test Statistic     -1.064912e+01
# p-value                 4.711026e-19
# # Lags                  0.000000e+00
# # Observations          2.500000e+02
# critical value (1%)    -3.456781e+00
# critical value (5%)    -2.873172e+00
# critical value (10%)   -2.572969e+00
# Data is stationary
#
#
# Column Name:  nasdaq
# ------------------------
# ADF Test Statistic       -4.794998
# p-value                   0.000056
# # Lags                   11.000000
# # Observations          239.000000
# critical value (1%)      -3.458011
# critical value (5%)      -2.873710
# critical value (10%)     -2.573256
# Data is stationary
#
#
# Column Name:  cac_40
# ------------------------
# ADF Test Statistic       -5.497472
# p-value                   0.000002
# # Lags                    5.000000
# # Observations          245.000000
# critical value (1%)      -3.457326
# critical value (5%)      -2.873410
# critical value (10%)     -2.573096
# Data is stationary
#
#
# Column Name:  gold_usd
# ------------------------
# ADF Test Statistic     -1.307564e+01
# p-value                 1.916678e-24
# # Lags                  0.000000e+00
# # Observations          2.500000e+02
# critical value (1%)    -3.456781e+00
# critical value (5%)    -2.873172e+00
# critical value (10%)   -2.572969e+00
# Data is stationary
#
#
# Column Name:  fed_rate
# ------------------------
# ADF Test Statistic       -3.309609
# p-value                   0.014454
# # Lags                   10.000000
# # Observations          240.000000
# critical value (1%)      -3.457894
# critical value (5%)      -2.873659
# critical value (10%)     -2.573229
# Data is stationary
#
#
# Column Name:  euro_libor
# ------------------------
# ADF Test Statistic       -4.589922
# p-value                   0.000135
# # Lags                   14.000000
# # Observations          236.000000
# critical value (1%)      -3.458366
# critical value (5%)      -2.873866
# critical value (10%)     -2.573339
# Data is stationary
#
#
# Column Name:  us_unemp
# ------------------------
# ADF Test Statistic       -2.944457
# p-value                   0.040417
# # Lags                    5.000000
# # Observations          245.000000
# critical value (1%)      -3.457326
# critical value (5%)      -2.873410
# critical value (10%)     -2.573096
# Data is stationary
#
#
# Column Name:  eu_unemp
# ------------------------
# ADF Test Statistic       -2.624521
# p-value                   0.088034
# # Lags                    5.000000
# # Observations          245.000000
# critical value (1%)      -3.457326
# critical value (5%)      -2.873410
# critical value (10%)     -2.573096
# Data is non-stationary
#
#
# Column Name:  us_retail
# ------------------------
# ADF Test Statistic       -5.024628
# p-value                   0.000020
# # Lags                   14.000000
# # Observations          236.000000
# critical value (1%)      -3.458366
# critical value (5%)      -2.873866
# critical value (10%)     -2.573339
# Data is stationary
#
#
# Column Name:  eu_retail
# ------------------------
# ADF Test Statistic       -4.738116
# p-value                   0.000071
# # Lags                   16.000000
# # Observations          234.000000
# critical value (1%)      -3.458608
# critical value (5%)      -2.873972
# critical value (10%)     -2.573396
# Data is stationary
#
#
# Column Name:  us_core_cpi
# ------------------------
# ADF Test Statistic     -5.973845e+00
# p-value                 1.908084e-07
# # Lags                  1.100000e+01
# # Observations          2.390000e+02
# critical value (1%)    -3.458011e+00
# critical value (5%)    -2.873710e+00
# critical value (10%)   -2.573256e+00
# Data is stationary
#
#
# Column Name:  Year
# ------------------------
# ADF Test Statistic     -3.617020e+15
# p-value                 0.000000e+00
# # Lags                  1.500000e+01
# # Observations          2.350000e+02
# critical value (1%)    -3.458487e+00
# critical value (5%)    -2.873919e+00
# critical value (10%)   -2.573367e+00
# Data is stationary

# %%
# Drop eu_unemp, as eu_unemployment is still stationary while every column isnt 
# and Year due to differencing its reflecting as 0 and 1 below the datetime unit
final_differ.drop(['eu_unemp', 'Year'], axis = 1, inplace= True)

# %%
final_differ.head()
# Out:
#              eur/usd   gbp/usd   usd/jpy   usd/chf  usd_index  wti_crude  \
# date
# 1999-02-28 -0.039295 -0.022907  3.347738  0.041869   2.486667  -0.482929
# 1999-03-31 -0.032245 -0.005972  2.852283  0.035438   2.335217   2.693674
# 1999-04-30 -0.018329 -0.013151  0.258399  0.031890   1.062964   2.604190
# 1999-05-31 -0.007531  0.006382  2.154913  0.013494   0.535152   0.416494
# 1999-06-30 -0.023764 -0.018855 -1.206732  0.028133   1.462121   0.217143
#
#                 nasdaq      cac_40   gold_usd  fed_rate  euro_libor  us_unemp  \
# date
# 1999-02-28    1.764881  -13.060738   0.240833  0.000000   -0.042690       0.1
# 1999-03-31   36.307500   15.547674  -1.822717  0.000000   -0.045239      -0.2
# 1999-04-30  147.754545  184.965099  -3.371146  0.000000   -0.351443       0.1
# 1999-05-31  -31.088355   34.265108  -5.801732  0.000000   -0.116818      -0.1
# 1999-06-30   13.152446   76.064892 -15.425541  0.238636    0.047273       0.1
#
#             us_retail  eu_retail  us_core_cpi
# date
# 1999-02-28        1.1        0.5         -0.3
# 1999-03-31       -0.1        1.1          0.0
# 1999-04-30       -0.6       -1.2          0.1
# 1999-05-31        0.5       -0.9         -0.2
# 1999-06-30       -0.6        1.7          0.1

# %%
# Generate autocorrelation plot on training data.
plot_acf(final_differ['eur/usd'], lags = 40);

# %%
# Generate partial autocorrelation plot on training data.
plot_pacf(final_differ['eur/usd'], lags = 40);

# %% [markdown]
# Analyzing the Auto Correlation and Partial Auto Correlation chart, we notice apart from the lag 1 there's no seasonality present in the EUR/USD monthly price from Jan 99 to Dec 19

# %% [markdown]
# #### Create Train/Test Split

# %%
# Arrange the last 6 months for prediction data
# Create a 80:20 train/test split on the remaining data sets
train = final_differ.iloc[:198]
test = final_differ.iloc[198:245]
test_prediction = final_differ.iloc[245:]

# %%
# Display the shape of the data set
print(train.shape)
print(test.shape)
print(test_prediction.shape)
# Out:
# (198, 15)
# (47, 15)
# (6, 15)

# %%
# Date index got switched to object after Dicky Fueller, reset the index to datetime
train = train.reset_index()
train["date"] = pd.to_datetime(train["date"])
train = train.set_index("date")
train.index
# Out:
# DatetimeIndex(['1999-02-28', '1999-03-31', '1999-04-30', '1999-05-31',
#                '1999-06-30', '1999-07-31', '1999-08-31', '1999-09-30',
#                '1999-10-31', '1999-11-30',
#                ...
#                '2014-10-31', '2014-11-30', '2014-12-31', '2015-01-31',
#                '2015-02-28', '2015-03-31', '2015-04-30', '2015-05-31',
#                '2015-06-30', '2015-07-31'],
#               dtype='datetime64[ns]', name='date', length=198, freq=None)

# %%
# Date index got switched to object after Dicky Fueller, reset the index to datetime
test = test.reset_index()
test["date"] = pd.to_datetime(test["date"])
test = test.set_index("date")
test.index
# Out:
# DatetimeIndex(['2015-08-31', '2015-09-30', '2015-10-31', '2015-11-30',
#                '2015-12-31', '2016-01-31', '2016-02-29', '2016-03-31',
#                '2016-04-30', '2016-05-31', '2016-06-30', '2016-07-31',
#                '2016-08-31', '2016-09-30', '2016-10-31', '2016-11-30',
#                '2016-12-31', '2017-01-31', '2017-02-28', '2017-03-31',
#                '2017-04-30', '2017-05-31', '2017-06-30', '2017-07-31',
#                '2017-08-31', '2017-09-30', '2017-10-31', '2017-11-30',
#                '2017-12-31', '2018-01-31', '2018-02-28', '2018-03-31',
#                '2018-04-30', '2018-05-31', '2018-06-30', '2018-07-31',
#                '2018-08-31', '2018-09-30', '2018-10-31', '2018-11-30',
#                '2018-12-31', '2019-01-31', '2019-02-28', '2019-03-31',
#                '2019-04-30', '2019-05-31', '2019-06-30'],
#               dtype='datetime64[ns]', name='date', freq=None)

# %% [markdown]
# ### Modeling

# %% [markdown]
# #### ARIMA

# %%
auto_arima(train['eur/usd'],seasonal=False).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  198
# Model:                     ARMA(0, 1)   Log Likelihood                 422.125
# Method:                       css-mle   S.D. of innovations              0.029
# Date:                Mon, 29 Jun 2020   AIC                           -838.250
# Time:                        09:09:02   BIC                           -828.385
# Sample:                             0   HQIC                          -834.257
#
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0004      0.003     -0.145      0.885      -0.006       0.005
# ma.L1.y        0.3278      0.066      4.963      0.000       0.198       0.457
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# MA.1           -3.0504           +0.0000j            3.0504            0.5000
# -----------------------------------------------------------------------------
# """

# %%
# Instantiate an AR(1) model on training data.
# Start at time period 198 and end at 244.
ar1 = ARIMA(endog = train['eur/usd'],
            order = (0, 1, 1)) # (p, d, q)

# Fit AR(1) model.
model_ar1 = ar1.fit()

# Generate predictions based on test set.
# Start at time period 198 and end at 244.
preds = model_ar1.predict(start=198, end=244)

# Evaluate predictions.
mean_squared_error(test['eur/usd'], preds)
# Out:
# C:\Users\Roshrav\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   % freq, ValueWarning)
# C:\Users\Roshrav\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   % freq, ValueWarning)
# 0.00030834044664017004

# %%
# Plot data.
plt.figure(figsize=(16,6))
# Plot training data in blue.
plt.plot(train['eur/usd'], color = 'blue')
# Plot testing data in orange.
plt.plot(test['eur/usd'], color = 'orange')
# Plot predicted values in green.
plt.plot(preds, color = 'green')
# Plot title
plt.title(label = 'EUR/USD Monthly', fontsize=18)
plt.show();

# %% [markdown]
# #### SARIMAX - Endogenous

# %%
# Plot SARIMAX model with Endogenous variable only
model_s1 = SARIMAX(train['eur/usd'],order=(0,1,1),seasonal_order=(0,0,0,0),enforce_invertibility=False)
results = model_s1.fit()
results.summary()
# Out:
# C:\Users\Roshrav\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   % freq, ValueWarning)
# C:\Users\Roshrav\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   % freq, ValueWarning)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                eur/usd   No. Observations:                  198
# Model:               SARIMAX(0, 1, 1)   Log Likelihood                 407.420
# Date:                Mon, 29 Jun 2020   AIC                           -810.840
# Time:                        09:20:22   BIC                           -804.274
# Sample:                    02-28-1999   HQIC                          -808.182
#                          - 07-31-2015
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -1.0537      0.023    -44.920      0.000      -1.100      -1.008
# sigma2         0.0008   7.61e-05     10.950      0.000       0.001       0.001
# ===================================================================================
# Ljung-Box (Q):                       90.91   Jarque-Bera (JB):                11.08
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.49   Skew:                            -0.25
# Prob(H) (two-sided):                  0.11   Kurtosis:                         4.05
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
# Obtain predicted values
start=198
end=244
predictions = results.predict(start=start, end=end, dynamic=False).rename('SARIMA(0,1,1) Predictions')

# %%
# Plot predictions against known test values
title='EUR/USD Monthly'
ylabel='Price'
xlabel=''

ax = test['eur/usd'].plot(legend=True,figsize=(12,6),title=title)
predictions.plot(legend=True)

ax.autoscale(axis='x',tight=True)
ax.set(xlabel=xlabel, ylabel=ylabel)
# Out:
# [Text(0, 0.5, 'Price'), Text(0.5, 0, '')]

# %% [markdown]
# #### SARIMAX - Exogenous Variables

# %%
# Plot SARIMAX with top 3 exogenous features
model_s2 = SARIMAX(train['eur/usd'],exog=train[['wti_crude', 'usd_index', 'usd/chf']],order=(0,1,1),seasonal_order=(0,0,0,0),enforce_invertibility=False)
results = model_s2.fit()
results.summary()
# Out:
# C:\Users\Roshrav\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   % freq, ValueWarning)
# C:\Users\Roshrav\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   % freq, ValueWarning)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                eur/usd   No. Observations:                  198
# Model:               SARIMAX(0, 1, 1)   Log Likelihood                 632.510
# Date:                Mon, 29 Jun 2020   AIC                          -1255.020
# Time:                        09:22:33   BIC                          -1238.604
# Sample:                    02-28-1999   HQIC                         -1248.375
#                          - 07-31-2015
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# wti_crude      0.0005   8.79e-05      5.604      0.000       0.000       0.001
# usd_index     -0.0155      0.001    -21.424      0.000      -0.017      -0.014
# usd/chf        0.0138      0.043      0.319      0.750      -0.071       0.099
# ma.L1         -1.0001      4.771     -0.210      0.834     -10.350       8.350
# sigma2      9.259e-05      0.000      0.209      0.834      -0.001       0.001
# ===================================================================================
# Ljung-Box (Q):                       38.62   Jarque-Bera (JB):                 4.66
# Prob(Q):                              0.53   Prob(JB):                         0.10
# Heteroskedasticity (H):               1.05   Skew:                             0.06
# Prob(H) (two-sided):                  0.86   Kurtosis:                         3.74
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
# Use test values with top 3 features for predictions
start=198
end=244
exog_forecast = test[['wti_crude', 'usd_index', 'usd/chf']]
predictions = results.predict(start=start, end=end, exog=exog_forecast).rename('SARIMAX(0,1,1) Predictions')

# %%
# Plot predictions against known values
title='EUR/USD Monthly'
ylabel='Price'
xlabel=''

ax = test['eur/usd'].plot(legend=True,figsize=(12,6),title=title)
predictions.plot(legend=True)
ax.autoscale(axis='x',tight=True)
ax.set(xlabel=xlabel, ylabel=ylabel)
# Out:
# [Text(0, 0.5, 'Price'), Text(0.5, 0, '')]

# %% [markdown]
# #### Evaluation

# %%
# Evaluate the model
mean_square = mse(test['eur/usd'], predictions)
rmse_eval = rmse(test['eur/usd'], predictions)

print(f'SARIMA(0,1,1) MSE Error: {mean_square:11.10}')
print(f'SARIMA(0,1,1) RMSE Error: {rmse_eval:11.10}')
# Out:
# SARIMA(0,1,1) MSE Error: 3.664870293e-05
# SARIMA(0,1,1) RMSE Error: 0.00605381722

# %% [markdown]
# #### Conclusion and Recommendation
